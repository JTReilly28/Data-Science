# %% [markdown]
# <a href="https://colab.research.google.com/github/JTReilly28/Data-Science/blob/main/Copy_of_lab01_hello_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🔧 **Setup**

# %%
# Install required libraries
# !pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📍 **Section 1: Series - One-Dimensional Data**

# %%
# Creating a Series
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ### 📘 What this does:
# * `pd.Series(...)` creates a one-dimensional array-like object.
# * `np.nan` stands for "Not a Number", a missing value.

# %% [markdown]
# ### ✏️ Exercise 1:
# * Create your own Series with names of fruits.
# * Include a missing value using `np.nan`.

# %%
# Your code here:
my_series = pd.Series(["apple", "banana", "avocado", np.nan, "watermelon"])

# %% [markdown]
# ## 📍 **Section 2: DataFrame - Two-Dimensional Data**
#
# ✅ 1. Tabular Data Representation
# Mimics a spreadsheet or SQL table: rows + labeled columns.
#
# Makes data easy to read, access, and interpret.
#
# ✅ 2. Labeled Indexing
# You can access data using row/column labels, not just numbers.
#
# This improves clarity and reduces errors in complex analyses.

# %%
# Create a datetime index
dates = pd.date_range("20220101", periods=6)
print(dates)
# Create a DataFrame with random numbers
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2022-01-01  0.166393  0.531951 -1.702970 -0.890029
# 2022-01-02 -0.486498  1.511860 -0.139597  0.926135
# 2022-01-03 -0.123952 -1.351469 -0.800354 -0.062655
# 2022-01-04 -0.088136 -0.026362  0.740610 -0.431530
# 2022-01-05 -1.527719 -0.333262  1.120605  0.901724
# 2022-01-06  0.948325  0.935777 -2.295036  1.379029

# %% [markdown]
# ### 📘 Explanation:
# * `date_range()` creates dates.
# * `np.random.randn()` creates random data.
# * `DataFrame(...)` builds a table from the array.

# %% [markdown]
# ### ✏️ Exercise 2:
# * Create a DataFrame with 5 rows, 3 columns (`X`, `Y`, `Z`), and use your own numbers.

# %%
df1 = pd.DataFrame(np.random.randn(5,3), index = my_series, columns = list("XYZ"))
df1
# Out:
#                    X         Y         Z
# apple      -1.407581  0.089727  0.816939
# banana     -0.708588  0.982958 -0.635599
# avocado    -0.140799  1.266886  1.104998
# NaN        -0.369191 -0.487652 -0.690863
# watermelon -0.453117 -0.448158  0.264364

# %% [markdown]
# ## 📍 **Section 3: DataFrame from a Dictionary**

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20220101"),
    "C": pd.Series([1, 2, 3, 4], dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo",
})
df2

# %% [markdown]
# ### 📘 Explanation:
# You can pass a Python dictionary to create a more structured and labeled dataset.

# %% [markdown]
# ### ✏️ Exercise 3:
# * Create a DataFrame with columns for your `name`, `age`, and `student status (True/False)`.

# %%
df2 = pd.DataFrame({
    "name": ["J.T.", "Ethan", "Hong", "Tony"],
    "age": [19, 19, 19, 22],
    "student status (True/False)": True,
})
df2
# Out:
#     name  age  student status (True/False)
# 0   J.T.   19                         True
# 1  Ethan   19                         True
# 2   Hong   19                         True
# 3   Tony   22                         True

# %% [markdown]
# ## 📍 **Section 4: Inspecting Data**

# %%
# View top and bottom rows
print(df.head())
print(df.tail())

# %%
# Show index and column names
print(df.index)
print(df.columns)

# %%
# Convert to NumPy array (for computation)
df.to_numpy()

# %%
# Check column data types
df2.dtypes

# %% [markdown]
# ### ✏️ Exercise 4:
# * Use `.head()` and `.tail()` to inspect your own DataFrame from Exercise 3.

# %%
print(df2.head())
print(df2.tail())
# Out:
#     name  age  student status (True/False)
# 0   J.T.   19                         True
# 1  Ethan   19                         True
# 2   Hong   19                         True
# 3   Tony   22                         True
#     name  age  student status (True/False)
# 0   J.T.   19                         True
# 1  Ethan   19                         True
# 2   Hong   19                         True
# 3   Tony   22                         True

# %% [markdown]
# ## 📍 **Section 5: Summary Statistics**

# %%
# Summary of statistics
df.describe()

# %%
# Transpose rows and columns
df.T

# %%
# Sort by column names
df.sort_index(axis=1, ascending=False)

# %%
# Sort by values in a specific column
df.sort_values(by="C")

# %% [markdown]
# ### ✏️ Exercise 5:
# * Add a new column `Score` to your DataFrame and sort it.

# %%
df2 = pd.DataFrame({
    "name": ["J.T.", "Ethan", "Hong", "Tony"],
    "age": [19, 19, 19, 22],
    "student status (True/False)": True,
})
df2["Score"]=[4,2,3,1]
df2.sort_values(by="Score")
# Out:
#     name  age  student status (True/False)  Score
# 3   Tony   22                         True      1
# 1  Ethan   19                         True      2
# 2   Hong   19                         True      3
# 0   J.T.   19                         True      4

# %% [markdown]
# ## 📍 **Section 6: Selecting Columns**

# %%
# Select a column using bracket notation
df["A"]

# %% [markdown]
# ### ✏️ Exercise 6:
# * Print the column `A` and plot it using `.plot()` (Optional: if you're in Colab or Jupyter)

# %%
df["A"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## ✅ **Final Task (Mini Project)**:
# Use what you've learned to:
# * Create a DataFrame with 5 students and their grades in Math, Science, and English.
# * Calculate the average for each student.
# * Sort the DataFrame by average grade.
# * Display summary statistics.

# %%
final = pd.DataFrame({
    "Student": ["J.T.", "Ethan", "Hong", "Tony", "Bob"],
    "Math Grade": [98, 42, 77, 90, 68],
    "Science Grade": [95, 39, 88, 75, 96],
    "English Grade": [87, 88, 33, 56, 97],
})
final["Average"] = (final["Math Grade"] + final["Science Grade"] + final["English Grade"]) / 3
sorted_final = final.sort_values(by="Average")
print(sorted_final)
print(final.describe())
# Out:
#   Student  Math Grade  Science Grade  English Grade    Average
# 1   Ethan          42             39             88  56.333333
# 2    Hong          77             88             33  66.000000
# 3    Tony          90             75             56  73.666667
# 4     Bob          68             96             97  87.000000
# 0    J.T.          98             95             87  93.333333
#        Math Grade  Science Grade  English Grade    Average
# count    5.000000       5.000000       5.000000   5.000000
# mean    75.000000      78.600000      72.200000  75.266667
# std     21.771541      23.670657      26.845856  15.091204
# min     42.000000      39.000000      33.000000  56.333333
# 25%     68.000000      75.000000      56.000000  66.000000
# 50%     77.000000      88.000000      87.000000  73.666667
# 75%     90.000000      95.000000      88.000000  87.000000
# max     98.000000      96.000000      97.000000  93.333333
